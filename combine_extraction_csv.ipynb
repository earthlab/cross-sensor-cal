# %%
import os
import shutil
from collections import defaultdict

def copy_and_sort_folders(base_folder, destination_folder, category_keywords):
    """
    Copies and sorts folders into like kinds based on predefined category keywords.

    Parameters:
    - base_folder (str): The path to the base directory containing the subdirectories to sort.
    - destination_folder (str): The path to the folder where sorted directories will be stored.
    - category_keywords (dict): A dictionary mapping category names to lists of keywords.
    """
    # Ensure destination folder exists
    os.makedirs(destination_folder, exist_ok=True)
    
    # Dictionary to store folders by category
    categorized_folders = defaultdict(list)
    
    # Identify subdirectories
    subdirectories = [
        d for d in os.listdir(base_folder)
        if os.path.isdir(os.path.join(base_folder, d)) and not d.startswith('.')
    ]
    
    # Categorize each folder
    for subdir in subdirectories:
        subdir_path = os.path.join(base_folder, subdir)
        assigned_category = None
        
        for category, keywords in category_keywords.items():
            if any(keyword in subdir.lower() for keyword in keywords):
                assigned_category = category
                break
        
        # If no category is found, assign to "Uncategorized"
        if assigned_category is None:
            assigned_category = "Uncategorized"
        
        categorized_folders[assigned_category].append(subdir_path)
    
    # Copy and sort into category folders
    for category, folders in categorized_folders.items():
        category_path = os.path.join(destination_folder, category)
        os.makedirs(category_path, exist_ok=True)
        
        for folder in folders:
            folder_name = os.path.basename(folder)
            dest_path = os.path.join(category_path, folder_name)
            
            if not os.path.exists(dest_path):
                shutil.copytree(folder, dest_path)
                print(f"📁 Copied '{folder_name}' to '{category}'")
            else:
                print(f"⚠️ Folder '{folder_name}' already exists in '{category}', skipping...")
    
    print("✅ Sorting complete.")

# Example usage:
# Define categories and associated keywords
category_keywords = {
    "Reflectance": ["reflectance", "brdf"],
    "Ancillary Data": ["ancillary", "config"],
    "Masking": ["mask", "masked"],
    "Topography": ["topo"],
}

# Call the function
# copy_and_sort_folders("/path/to/base_folder", "/path/to/destination_folder", category_keywords)
